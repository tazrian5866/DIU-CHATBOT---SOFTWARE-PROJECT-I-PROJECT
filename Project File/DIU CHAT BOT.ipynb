# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ChatBot.csv', encoding='utf-8')

# %%
path = "/content/drive/MyDrive/Colab Notebooks/ChatBot.csv"
file1 = open(path, "r")

# %%
# Print the path of file                        OPTIONAL CHECK

file1.name

# %%
# Print the mode of file, either 'r' or 'w'                 OPTIONAL CHECK

file1.mode

# %%
# Read the file                     OPTIONAL CHECK

FileContent = file1.read()
FileContent

# %%
# Print the file with '\n' as a new line                     OPTIONAL CHECK

print(FileContent)

# %%
# PRINTING  XL FILE
pd.read_csv(path)
df.head(5)
# Out:
#                         Unnamed: 0    Unnamed: 1      Unnamed: 2  \
# 0                              NaN           NaN             NaN
# 1                            Cost            NaN             NaN
# 2                         Question        Answer            TYPE
# 3  Total Cost of DIU B.Sc in CSE ?  8 LAKH 90000      Total Cost
# 4                      Hall costs?         15000  Every Semester
#
#    DATA COLLECTION FOR  DIU CHAT BOT 1.0 PROJECT  \
# 0                                            NaN
# 1                                      Admission
# 2                                       Question
# 3                                Admission time?
# 4                           Semester's in B.sc ?
#
#                                           Unnamed: 4  \
# 0                                                NaN
# 1                                                NaN
# 2                                             Answer
# 3  Currently only available during Spring and fal...
# ...

# %%
# SEARCH WITH PYTHON
search_results = df[df['TYPE'].str.contains("Admission Time")]
print(search_results)

# %%
# Close file after finish

file1.close()
